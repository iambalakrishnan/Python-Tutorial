# %%
#For MySQL
# !pip install mysql-connector-python

#For oracle
#!pip install cx-Oracle
# Out:
# ...
#      |████████████████████████████████| 38.0 MB 12.3 MB/s eta 0:00:01     |███████████████████████▊        | 28.2 MB 12.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.1 MB 12.4 MB/s eta 0:00:01
# ...

# %%
import mysql.connector as conn

# %%
#Establish the connection 
my_conn = conn.connect(host='localhost',user = 'root', passwd = 'Admin*#12345')

# %%
my_conn

# %%
query = "show databases"

# %%
#get the cursor(like pointer) with defined connection 
cursor = my_conn.cursor()

#execute the query over the cursor object
cursor.execute(query)

#cursor.execute("show databases")

# %%
#to view the output result we need to call fetchall() over cursor object
cursor.fetchall()
# Out:
# [('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sample',),
#  ('std',),
#  ('sys',)]

# %% [markdown]
# ## Create database

# %%
cursor = my_conn.cursor()
cursor.execute("CREATE DATABASE test1")

# %%
cursor.fetchall()
# Out:
# []

# %%
cursor = my_conn.cursor()
cursor.execute("SHOW DATABASES")

# %%
cursor.fetchall()
# Out:
# [('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sample',),
#  ('std',),
#  ('sys',),
#  ('test1',)]

# %% [markdown]
# ## Close connection

# %%
my_conn.close()

# %%
#To check wheather the connection is alive or not

my_conn.is_connected()
# Out:
# False

# %%
#Establishing the connection

mydb = conn.connect(host='localhost',user = 'root', passwd = 'Admin*#12345')

#mydb = conn.connect(host='localhost',user = 'root', passwd = 'Admin*#12345', database = test1')

# %%
mydb.is_connected()
# Out:
# True

# %%
query = "CREATE TABLE test1.students (Id INT(10), Name VARCHAR(25), DOB DATE, course VARCHAR(20),city VARCHAR(15))"

#query = "CREATE TABLE students (Id INT(10), Name VARCHAR(25), DOB DATE, course VARCHAR(20),city VARCHAR(15))"

# %%
cursor = mydb.cursor()
cursor.execute(query)

# %%
#creating new table
query = "CREATE TABLE test1.employee (empno decimal(4,0) NOT NULL,ename varchar(10) default NULL,job varchar(9) default NULL,mgr decimal(4,0) default NULL,hiredate date default NULL,sal decimal(7,2) default NULL,comm decimal(7,2) default NULL,deptno decimal(2,0) default NULL)"

# %%
cursor = mydb.cursor()
cursor.execute(query)

# %%
query1 = "CREATE TABLE test1.department (deptno decimal(2,0) default NULL,dname varchar(14) default NULL,loc varchar(13) default NULL)"

# %%
cursor = mydb.cursor()
cursor.execute(query1)

# %%
cursor = mydb.cursor()
cursor.execute("show databases")

# %%
cursor.fetchall()
# Out:
# [('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sample',),
#  ('std',),
#  ('sys',),
#  ('test1',)]

# %%
#we need to use database to fetch details from the database
cursor = mydb.cursor()
cursor.execute("use test1")

# %%
cursor = mydb.cursor()
cursor.execute("show tables")

# %%
cursor.fetchall()
# Out:
# [('department',), ('employee',), ('students',)]

# %%
mydb.close()

# %%
mydb.is_connected()
# Out:
# False

# %%
#Re establish connection with selected database by default
mydb = conn.connect(host='localhost',user = 'root', passwd = 'Admin*#12345', database = 'test1')

# %%
mydb.is_connected()
# Out:
# True

# %%
cursor = mydb.cursor()
cursor.execute("show tables")

# %%
cursor.fetchall()
# Out:
# [('department',), ('employee',), ('students',)]

# %%
cursor.execute("INSERT INTO employee VALUES ('7369','SMITH','CLERK','7902','1980-12-17','800.00',NULL,'20')")

# %%
cursor.execute("select * from employee")

# %%
cursor.fetchall()
# Out:
# [(Decimal('7369'),
#   'SMITH',
#   'CLERK',
#   Decimal('7902'),
#   datetime.date(1980, 12, 17),
#   Decimal('800.00'),
#   None,
#   Decimal('20'))]

# %%
cursor.execute("commit")
#mydb.commit()

# %%
cursor.execute("INSERT INTO department VALUES ('10','ACCOUNTING','NEW YORK')")

# %%
mydb.commit()

# %%
cursor.execute("SELECT * from department")

# %%
cursor.fetchall()
# Out:
# [(Decimal('10'), 'ACCOUNTING', 'NEW YORK')]

# %%
cursor.execute("INSERT INTO employee VALUES ('7499','ALLEN','SALESMAN','7698','1981-02-20','1600.00','300.00','30')")

# %%
cursor.execute("INSERT INTO employee VALUES ('7521','WARD','SALESMAN','7698','1981-02-22','1250.00','500.00','30')")
cursor.execute("INSERT INTO employee VALUES ('7566','JONES','MANAGER','7839','1981-04-02','2975.00',NULL,'20')")

# %%
mydb.commit()

# %%
cursor.execute("INSERT INTO employee VALUES ('7654','MARTIN','SALESMAN','7698','1981-09-28','1250.00','1400.00','30')")
cursor.execute("INSERT INTO employee VALUES ('7698','BLAKE','MANAGER','7839','1981-05-01','2850.00',NULL,'30')")
cursor.execute("INSERT INTO employee VALUES ('7782','CLARK','MANAGER','7839','1981-06-09','2450.00',NULL,'10')")
cursor.execute("INSERT INTO employee VALUES ('7788','SCOTT','ANALYST','7566','1982-12-09','3000.00',NULL,'20')")
cursor.execute("INSERT INTO employee VALUES ('7839','KING','PRESIDENT',NULL,'1981-11-17','5000.00',NULL,'10')")
cursor.execute("INSERT INTO employee VALUES ('7844','TURNER','SALESMAN','7698','1981-09-08','1500.00','0.00','30')")
cursor.execute("INSERT INTO employee VALUES ('7876','ADAMS','CLERK','7788','1983-01-12','1100.00',NULL,'20')")
cursor.execute("INSERT INTO employee VALUES ('7902','FORD','ANALYST','7566','1981-12-03','3000.00',NULL,'20')")
cursor.execute("INSERT INTO employee VALUES ('7934','MILLER','CLERK','7782','1982-01-23','1300.00',NULL,'10')")

# %%
cursor.execute("INSERT INTO department VALUES ('20','RESEARCH','DALLAS')")
cursor.execute("INSERT INTO department VALUES ('30','SALES','CHICAGO')")
cursor.execute("INSERT INTO department VALUES ('40','OPERATIONS','BOSTON')")

# %%
mydb.commit()

# %%
cursor.execute("SELECT * FROM employee")

# %%
cursor.fetchall()
# Out:
# [(Decimal('7369'),
#   'SMITH',
#   'CLERK',
#   Decimal('7902'),
#   datetime.date(1980, 12, 17),
#   Decimal('800.00'),
#   None,
#   Decimal('20')),
#  (Decimal('7499'),
#   'ALLEN',
#   'SALESMAN',
#   Decimal('7698'),
#   datetime.date(1981, 2, 20),
#   Decimal('1600.00'),
#   Decimal('300.00'),
#   Decimal('30')),
#  (Decimal('7521'),
#   'WARD',
#   'SALESMAN',
#   Decimal('7698'),
#   datetime.date(1981, 2, 22),
#   Decimal('1250.00'),
#   Decimal('500.00'),
#   Decimal('30')),
#  (Decimal('7566'),
#   'JONES',
#   'MANAGER',
#   Decimal('7839'),
#   datetime.date(1981, 4, 2),
#   Decimal('2975.00'),
#   None,
#   Decimal('20')),
#  (Decimal('7654'),
#   'MARTIN',
#   'SALESMAN',
#   Decimal('7698'),
#   datetime.date(1981, 9, 28),
#   Decimal('1250.00'),
#   Decimal('1400.00'),
#   Decimal('30')),
#  (Decimal('7698'),
#   'BLAKE',
#   'MANAGER',
#   Decimal('7839'),
#   datetime.date(1981, 5, 1),
#   Decimal('2850.00'),
#   None,
#   Decimal('30')),
#  (Decimal('7782'),
# ...

# %%
cursor.execute("SELECT * FROM department")

# %%
cursor.fetchall()
# Out:
# [(Decimal('10'), 'ACCOUNTING', 'NEW YORK'),
#  (Decimal('20'), 'RESEARCH', 'DALLAS'),
#  (Decimal('30'), 'SALES', 'CHICAGO'),
#  (Decimal('40'), 'OPERATIONS', 'BOSTON')]

# %%
import pandas as pd

# %% [markdown]
# ## pd.read_sql()
#
# pd.read_sql(
#     sql,
#     con,
#     index_col: 'str | Sequence[str] | None' = None,
#     coerce_float: 'bool' = True,
#     params=None,
#     parse_dates=None,
#     columns=None,
#     chunksize: 'int | None' = None,
# ) -> 'DataFrame | Iterator[DataFrame]'
# Docstring:
# Read SQL query or database table into a DataFrame.
#
# This function is a convenience wrapper around ``read_sql_table`` and
# ``read_sql_query`` (for backward compatibility). It will delegate
# to the specific function depending on the provided input. A SQL query
# will be routed to ``read_sql_query``, while a database table name will
# be routed to ``read_sql_table``. Note that the delegated function might
# have more specific notes about their functionality not listed here.
#
# Parameters
# ----------
# sql : str or SQLAlchemy Selectable (select or text object)
#     SQL query to be executed or a table name.
# con : SQLAlchemy connectable, str, or sqlite3 connection
#     Using SQLAlchemy makes it possible to use any DB supported by that
#     library. If a DBAPI2 object, only sqlite3 is supported. The user is responsible
#     for engine disposal and connection closure for the SQLAlchemy connectable; str
#     connections are closed automatically. See
#     `here <https://docs.sqlalchemy.org/en/13/core/connections.html>`_.
# index_col : str or list of str, optional, default: None
#     Column(s) to set as index(MultiIndex).
#
# coerce_float : bool, default True
#     Attempts to convert values of non-string, non-numeric objects (like
#     decimal.Decimal) to floating point, useful for SQL result sets.
#
# params : list, tuple or dict, optional, default: None
#     List of parameters to pass to execute method.  The syntax used
#     to pass parameters is database driver dependent. Check your
#     database driver documentation for which of the five syntax styles,
#     described in PEP 249's paramstyle, is supported.
#     Eg. for psycopg2, uses %(name)s so use params={'name' : 'value'}.
#
# parse_dates : list or dict, default: None
#     - List of column names to parse as dates.
#     - Dict of ``{column_name: format string}`` where format string is
#       strftime compatible in case of parsing string times, or is one of
#       (D, s, ns, ms, us) in case of parsing integer timestamps.
#     - Dict of ``{column_name: arg dict}``, where the arg dict corresponds
#       to the keyword arguments of :func:`pandas.to_datetime`
#       Especially useful with databases without native Datetime support,
#       such as SQLite.
#
# columns : list, default: None
#     List of column names to select from SQL table (only used when reading
#     a table).
#
# chunksize : int, default None
#     If specified, return an iterator where `chunksize` is the
#     number of rows to include in each chunk.
#
#
# Returns
# -------
# DataFrame or Iterator[DataFrame]
#
#
# See Also
# --------
# read_sql_table : Read SQL database table into a DataFrame.
# read_sql_query : Read SQL query into a DataFrame.
#
#
# Examples
# --------
# Read data from SQL via either a SQL query or a SQL tablename.
# When using a SQLite database only SQL queries are accepted,
# providing only the SQL tablename will result in an error.
#
#
#     >>> from sqlite3 import connect
#     >>> conn = connect(':memory:')
#     >>> df = pd.DataFrame(data=[[0, '10/11/12'], [1, '12/11/10']],
#     ...                   columns=['int_column', 'date_column'])
#     >>> df.to_sql('test_data', conn)
#
#     >>> pd.read_sql('SELECT int_column, date_column FROM test_data', conn)
#        int_column date_column
#     0           0    10/11/12
#     1           1    12/11/10
#
#     >>> pd.read_sql('test_data', 'postgres:///db_name')  # doctest:+SKIP
#
# Apply date parsing to columns through the ``parse_dates`` argument
#
#     >>> pd.read_sql('SELECT int_column, date_column FROM test_data',
#     ...             conn,
#     ...             parse_dates=["date_column"])
#        int_column date_column
#     0           0  2012-10-11
#     1           1  2010-12-11
#
# The ``parse_dates`` argument calls ``pd.to_datetime`` on the provided columns.
# Custom argument values for applying ``pd.to_datetime`` on a column are specified
# via a dictionary format:
# 1. Ignore errors while parsing the values of "date_column"
#
#         pd.read_sql('SELECT int_column, date_column FROM test_data',
#         ...             conn,
#         ...             parse_dates={"date_column": {"errors": "ignore"}})
#            int_column date_column
#         0           0  2012-10-11
#         1           1  2010-12-11
#
# 2. Apply a dayfirst date parsing order on the values of "date_column"
#
#         >>> pd.read_sql('SELECT int_column, date_column FROM test_data',
#         ...             conn,
#         ...             parse_dates={"date_column": {"dayfirst": True}})
#            int_column date_column
#         0           0  2012-11-10
#         1           1  2010-11-12
#
# 3. Apply custom formatting when date parsing the values of "date_column"
#
#         >>> pd.read_sql('SELECT int_column, date_column FROM test_data',
#         ...             conn,
#         ...             parse_dates={"date_column": {"format": "%d/%m/%y"}})
#            int_column date_column
#         0           0  2012-11-10
#         1           1  2010-11-12
#         File:      ~/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py
#         Type:      function

# %%
df = pd.read_sql("SELECT * FROM employee", mydb)

# %%
df
# Out:
#      empno   ename        job     mgr    hiredate     sal    comm  deptno
# 0   7369.0   SMITH      CLERK  7902.0  1980-12-17   800.0     NaN    20.0
# 1   7499.0   ALLEN   SALESMAN  7698.0  1981-02-20  1600.0   300.0    30.0
# 2   7521.0    WARD   SALESMAN  7698.0  1981-02-22  1250.0   500.0    30.0
# 3   7566.0   JONES    MANAGER  7839.0  1981-04-02  2975.0     NaN    20.0
# 4   7654.0  MARTIN   SALESMAN  7698.0  1981-09-28  1250.0  1400.0    30.0
# 5   7698.0   BLAKE    MANAGER  7839.0  1981-05-01  2850.0     NaN    30.0
# 6   7782.0   CLARK    MANAGER  7839.0  1981-06-09  2450.0     NaN    10.0
# 7   7788.0   SCOTT    ANALYST  7566.0  1982-12-09  3000.0     NaN    20.0
# 8   7839.0    KING  PRESIDENT     NaN  1981-11-17  5000.0     NaN    10.0
# 9   7844.0  TURNER   SALESMAN  7698.0  1981-09-08  1500.0     0.0    30.0
# 10  7876.0   ADAMS      CLERK  7788.0  1983-01-12  1100.0     NaN    20.0
# 11  7902.0    FORD    ANALYST  7566.0  1981-12-03  3000.0     NaN    20.0
# ...

# %%
df1 = pd.read_sql("SELECT * FROM department", mydb)

# %%
df1
# Out:
#    deptno       dname       loc
# 0    10.0  ACCOUNTING  NEW YORK
# 1    20.0    RESEARCH    DALLAS
# 2    30.0       SALES   CHICAGO
# 3    40.0  OPERATIONS    BOSTON

# %%
ls
# Out:
# glass.data  MySQL_Connection.ipynb

# %%
query = "CREATE TABLE test1.glassdata(index1 INT(10),RI float(10,5),Na float(10,5),Mg float(10,5),Al float(10,5),Si FLOAT(10,5),K float(10,5),Ca float(10,5),Ba float(10,5),Fe float(10,5),Class INT(5))"

# %%
cursor.execute(query)

# %%
import csv

# %%
with open ("glass.data","r") as f:
    glass_data = csv.reader(f, delimiter = "\n")
    for lines in enumerate(glass_data):
        for i in lines[1]:
            print(i)
            cursor.execute("INSERT INTO glassdata VALUES ({values})".format(values = (i)))
    mydb.commit()
# Out:
# 1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1
# 2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1
# 3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1
# 4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1
# 5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1
# 6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1
# 7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1
# 8,1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0.00,0.00,1
# 9,1.51918,14.04,3.58,1.37,72.08,0.56,8.30,0.00,0.00,1
# 10,1.51755,13.00,3.60,1.36,72.99,0.57,8.40,0.00,0.11,1
# 11,1.51571,12.72,3.46,1.56,73.20,0.67,8.09,0.00,0.24,1
# 12,1.51763,12.80,3.66,1.27,73.01,0.60,8.56,0.00,0.00,1
# 13,1.51589,12.88,3.43,1.40,73.28,0.69,8.05,0.00,0.24,1
# 14,1.51748,12.86,3.56,1.27,73.21,0.54,8.38,0.00,0.17,1
# 15,1.51763,12.61,3.59,1.31,73.29,0.58,8.50,0.00,0.00,1
# 16,1.51761,12.81,3.54,1.23,73.24,0.58,8.39,0.00,0.00,1
# 17,1.51784,12.68,3.67,1.16,73.11,0.61,8.70,0.00,0.00,1
# ...

# %%
with open ("glass.data","r") as f:
    glass_data = csv.reader(f, delimiter = "\n")
    
    for lines in enumerate(glass_data):
        print(lines)
        for i in lines[1]:
            pass
            #print(i)
            #cursor.execute("INSERT INTO glassdata VALUES ({values})".format(values = (i)))
    #mydb.commit()
# Out:
# (0, ['1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1'])
# (1, ['2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1'])
# (2, ['3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1'])
# (3, ['4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1'])
# (4, ['5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1'])
# (5, ['6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1'])
# (6, ['7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1'])
# (7, ['8,1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0.00,0.00,1'])
# (8, ['9,1.51918,14.04,3.58,1.37,72.08,0.56,8.30,0.00,0.00,1'])
# (9, ['10,1.51755,13.00,3.60,1.36,72.99,0.57,8.40,0.00,0.11,1'])
# (10, ['11,1.51571,12.72,3.46,1.56,73.20,0.67,8.09,0.00,0.24,1'])
# (11, ['12,1.51763,12.80,3.66,1.27,73.01,0.60,8.56,0.00,0.00,1'])
# (12, ['13,1.51589,12.88,3.43,1.40,73.28,0.69,8.05,0.00,0.24,1'])
# (13, ['14,1.51748,12.86,3.56,1.27,73.21,0.54,8.38,0.00,0.17,1'])
# (14, ['15,1.51763,12.61,3.59,1.31,73.29,0.58,8.50,0.00,0.00,1'])
# ...

# %%
with open ("glass.data","r") as f:
    glass_data = csv.reader(f, delimiter = "\n")
    for lines in enumerate(glass_data):
        #print(lines)
        for i in lines[1]:
            #pass
            print(i)
            #cursor.execute("INSERT INTO glassdata VALUES ({values})".format(values = (i)))
    #mydb.commit()
# Out:
# 1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1
# 2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1
# 3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1
# 4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1
# 5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1
# 6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1
# 7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1
# 8,1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0.00,0.00,1
# 9,1.51918,14.04,3.58,1.37,72.08,0.56,8.30,0.00,0.00,1
# 10,1.51755,13.00,3.60,1.36,72.99,0.57,8.40,0.00,0.11,1
# 11,1.51571,12.72,3.46,1.56,73.20,0.67,8.09,0.00,0.24,1
# 12,1.51763,12.80,3.66,1.27,73.01,0.60,8.56,0.00,0.00,1
# 13,1.51589,12.88,3.43,1.40,73.28,0.69,8.05,0.00,0.24,1
# 14,1.51748,12.86,3.56,1.27,73.21,0.54,8.38,0.00,0.17,1
# 15,1.51763,12.61,3.59,1.31,73.29,0.58,8.50,0.00,0.00,1
# 16,1.51761,12.81,3.54,1.23,73.24,0.58,8.39,0.00,0.00,1
# 17,1.51784,12.68,3.67,1.16,73.11,0.61,8.70,0.00,0.00,1
# ...

# %%
df2 = pd.read_sql("SELECT * FROM glassdata", mydb)

# %%
df2
# Out:
#      index1       RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Class
# 0         1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0      1
# 1         2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0      1
# 2         3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0      1
# 3         4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0      1
# 4         5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0      1
# ..      ...      ...    ...   ...   ...    ...   ...   ...   ...  ...    ...
# 209     210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0      7
# 210     211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0      7
# 211     212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0      7
# 212     213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0      7
# 213     214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0      7
#
# [214 rows x 11 columns]

# %% [markdown]
# ## Delete data

# %%
cursor.execute("DELETE FROM glassdata WHERE index1 = 1")

# %%
mydb.commit()

# %%
cursor.execute("SELECT * FROM glassdata")

# %%
cursor.fetchall()
# Out:
# [(2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (4, 1.51766, 13.21, 3.69, 1.29, 72.61, 0.57, 8.22, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
#  (15, 1.51763, 12.61, 3.59, 1.31, 73.29, 0.58, 8.5, 0.0, 0.0, 1),
# ...

# %% [markdown]
# ## Update data

# %%
cursor.execute("UPDATE glassdata SET index1 = 200 WHERE index1 = 2")

# %%
mydb.commit()

# %%
cursor.execute("SELECT * FROM glassdata")

# %%
cursor.fetchall()
# Out:
# [(200, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (4, 1.51766, 13.21, 3.69, 1.29, 72.61, 0.57, 8.22, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
#  (15, 1.51763, 12.61, 3.59, 1.31, 73.29, 0.58, 8.5, 0.0, 0.0, 1),
# ...

# %%
cursor.execute("SELECT * FROM glassdata WHERE index1=200")

# %%
cursor.fetchall()
# Out:
# [(200, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (200, 1.51609, 15.01, 0.0, 2.51, 73.05, 0.05, 8.83, 0.53, 0.0, 7)]
